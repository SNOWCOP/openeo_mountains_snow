# %% [markdown]
# Test each pipeline step independently

# %% [markdown]
# ## 1. Imports & Load Config

# %%
import sys
from pathlib import Path
import openeo
import xarray as xr
import matplotlib.pyplot as plt
from omegaconf import OmegaConf

# Load the unified Hydra config WITHOUT @hydra.main (notebook-friendly)
PACKAGE_ROOT = Path(r"c:\Git_projects\openeo_mountains_snow\src\openeo_mountains_snow")
sys.path.insert(0, str(PACKAGE_ROOT.parent))

from openeo_mountains_snow.spatial_extent_utils import resolve_aoi, bbox_to_geometry

base_cfg = OmegaConf.load(PACKAGE_ROOT / "conf" / "config.yaml")
exp_cfg = OmegaConf.load(PACKAGE_ROOT / "conf" / "experiment" / "reconstruction.yaml")

# Merge experiment into the base config under "experiment" key
cfg = OmegaConf.merge(base_cfg, {"experiment": exp_cfg})
print(OmegaConf.to_yaml(cfg))
# Out:
# connection:
#   endpoint: openeo.dataspace.copernicus.eu
# sentinel2_l2a:
#   collection: SENTINEL2_L2A
#   scl_band: SCL
#   cloud_values:
#   - 8
#   - 9
#   - 3
#   - 10
# sentinel2_l1c:
#   collection: SENTINEL2_L1C
#   bands:
#   - B02
#   - B03
#   - B04
#   - B08
#   - B11
#   - sunZenithAngles
#   - sunAzimuthAngles
# water_mask:
#   collection: ESA_WORLDCOVER_10M_2021_V2
#   band: MAP
#   water_values:
#   - 80
# modis:
#   stac_url: https://stac.eurac.edu/collections/MOD10A1v61
# agera5:
#   stac_url: https://stac.openeo.vito.be/collections/agera5_daily
#   bands:
#   - 2m_temperature_mean
#   - dewpoint_temperature_mean
#   - solar_radiation_flux
#   band_aliases:
#   - temperature-mean
#   - dewpoint-temperature
#   - solar-radiation-flux
# geopotential:
#   stac_url: https://stac.openeo.vito.be/collections/geopotential
# dem:
#   slope_stac_url: https://stac.openeo.vito.be/collections/DEM_slope_30m
#   aspect_stac_url: https://stac.openeo.vito.be/collections/DEM_aspec_30m
# processing:
#   crs: 32632
#   resolution: 20.0
#   cloud_prob: 80
#   pixel_ratio: 25
#   invalid_value: 255
#   invalid_threshold: 10
#   delta: 10
#   epsilon: 10
#   modis_resolution: 25
# reconstruction:
#   n_days: 5
#   neighborhood_size: 64
# experiment:
#   pipeline: reconstruction
#   aoi:
#     west: 631800.0
#     south: 5170700.0
#     east: 637800.0
#     north: 5176200.0
#     crs: EPSG:32632
#   aoi_crs: null
#   temporal_extent:
#   - '2021-09-01'
#   - '2024-09-30'
#   modis_temporal_extent:
#   - '2023-01-20'
#   - '2023-01-21'
#   agera_temporal_extent:
#   - '2023-07-01'
#   - '2023-07-05'
#   title_prefix: swe_reconstruction
#   job_options:
#     executor-memory: 8G
#     executor-memoryOverhead: 500m
#     python-memory: 15G
# corsa_job: null

# %% [markdown]
# ## 2. Connect to openEO

# %%
eoconn = openeo.connect(cfg.connection.endpoint).authenticate_oidc()
# Out:
# Authenticated using refresh token.

# %% [markdown]
# ## 3. Define a TINY test extent
#
# Use a much smaller spatial/temporal extent than the real experiment so each `.execute()` completes in seconds, not hours. Override the config values here.

# %%
# ---- Test extent (≈10km x 10km, 5 days) ----
# Plain bbox dict — the standard format everywhere
# NOTE: MODIS STAC (Eurac) covers only the Senales catchment:
#   x: [632050, 655550], y: [5167950, 5183950] (EPSG:32632)
#   time: 2016-01-01 to 2023-02-01
spatial_extent = {
    "west": 635000.0,
    "south": 5170000.0,
    "east": 645000.0,   # 10 km
    "north": 5180000.0, # 10 km
    "crs": "EPSG:32632",
}
temporal_extent = ["2023-01-10", "2023-01-15"]  # within MODIS range (ends 2023-02-01)

# For MODIS / AGERA steps later
modis_temporal_extent = ["2023-01-10", "2023-01-15"]
agera_temporal_extent = ["2023-01-10", "2023-01-15"]

proc = cfg.processing
recon = cfg.reconstruction
print(f"Test bbox: {spatial_extent}")
print(f"Test period: {temporal_extent}")
# Out:
# Test bbox: {'west': 635000.0, 'south': 5170000.0, 'east': 645000.0, 'north': 5180000.0, 'crs': 'EPSG:32632'}
# Test period: ['2023-01-10', '2023-01-15']

# %% [markdown]
# ## 5. Test: Snow Cover Fraction (spectral indices + representative pixels)
#
# This is the improved SCF from `snow_cover_fraction.py` — the whole point of the integration. Download and visualize.

# %%
from openeo_mountains_snow.snow_cover_fraction import snow_cover_fraction_cube

snow = snow_cover_fraction_cube(
    spatial_extent=spatial_extent,
    time_period=temporal_extent,
    c=eoconn,
    cfg=cfg,
).rename_labels(dimension="bands", target=["snow"])

# Download as NetCDF and inspect
snow.download("test_snow.nc")
ds = xr.open_dataset("test_snow.nc")
print(ds)

# Plot first timestep
ds["snow"].isel(t=0).plot(figsize=(6, 5), cmap="Blues")
plt.title("Snow Cover Fraction (spectral indices + representative pixels)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OpenEoApiError                            Traceback (most recent call last)
# Cell In[4], line 11
#       3 snow = snow_cover_fraction_cube(
#       4     spatial_extent=spatial_extent,
#       5     time_period=temporal_extent,
#       6     c=eoconn,
#       7     cfg=cfg,
#       8 ).rename_labels(dimension="bands", target=["snow"])
#      10 # Download as NetCDF and inspect
# ---> 11 snow.download("test_snow.nc")
#      12 ds = xr.open_dataset("test_snow.nc")
#      13 print(ds)
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\datacube.py:2482, in DataCube.download(self, outputfile, format, options, validate, auto_add_save_result, additional, job_options, on_response_headers)
#    2480 else:
#    2481     res = self
# -> 2482 return self._connection.download(
#    2483     res.flat_graph(),
#    2484     outputfile=outputfile,
#    2485     validate=validate,
#    2486     additional=additional,
#    2487     job_options=job_options,
#    2488     on_response_headers=on_response_headers,
#    2489 )
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\connection.py:1761, in Connection.download(self, graph, outputfile, timeout, validate, chunk_size, additional, job_options, on_response_headers)
#    1757 pg_with_metadata = self._build_request_with_process_graph(
#    1758     process_graph=graph, additional=additional, job_options=job_options
#    1759 )
#    1760 self._preflight_validation(pg_with_metadata=pg_with_metadata, validate=validate)
# -> 1761 response = self.post(
#    1762     path="/result",
#    1763     json=pg_with_metadata,
#    1764     expected_status=200,
#    1765     stream=True,
#    1766     timeout=timeout or DEFAULT_TIMEOUT_SYNCHRONOUS_EXECUTE,
#    1767 )
#    1768 if on_response_headers := (on_response_headers or self._on_response_headers_sync):
#    1769     on_response_headers(response.headers)
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\_connection.py:232, in RestApiConnection.post(self, path, json, **kwargs)
#     224 def post(self, path: str, json: Optional[dict] = None, **kwargs) -> Response:
#     225     """
#     226     Do POST request to REST API.
#     227
#    (...)    230     :return: response: Response
#     231     """
# --> 232     return self.request("post", path=path, json=json, allow_redirects=False, **kwargs)
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\connection.py:774, in Connection.request(self, method, path, headers, auth, check_error, expected_status, **kwargs)
#     767     return super(Connection, self).request(
#     768         method=method, path=path, headers=headers, auth=auth,
#     769         check_error=check_error, expected_status=expected_status, **kwargs,
#     770     )
#     772 try:
#     773     # Initial request attempt
# --> 774     return _request()
#     775 except OpenEoApiError as api_exc:
#     776     if (
#     777         api_exc.http_status_code in {HTTP_401_UNAUTHORIZED, HTTP_403_FORBIDDEN}
#     778         and api_exc.code == "TokenInvalid"
#     779     ):
#     780         # Retry if we can refresh the access token
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\connection.py:767, in Connection.request.<locals>._request()
#     766 def _request():
# --> 767     return super(Connection, self).request(
#     768         method=method, path=path, headers=headers, auth=auth,
#     769         check_error=check_error, expected_status=expected_status, **kwargs,
#     770     )
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\_connection.py:141, in RestApiConnection.request(self, method, path, params, headers, auth, check_error, expected_status, **kwargs)
#     139 expected_status = ensure_list(expected_status) if expected_status else []
#     140 if check_error and status >= 400 and status not in expected_status:
# --> 141     self._raise_api_error(resp)
#     142 if expected_status and status not in expected_status:
#     143     raise OpenEoRestError(
#     144         "Got status code {s!r} for `{m} {p}` (expected {e!r}) with body {body}".format(
#     145             m=method.upper(), p=path, s=status, e=expected_status, body=resp.text
#     146         )
#     147     )
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\_connection.py:163, in RestApiConnection._raise_api_error(self, response)
#     161     error_message = info.get("message")
#     162     if error_code and isinstance(error_code, str) and error_message and isinstance(error_message, str):
# --> 163         raise OpenEoApiError(
#     164             http_status_code=status_code,
#     165             code=error_code,
#     166             message=error_message,
#     167             id=info.get("id"),
#     168             url=info.get("url"),
#     169         )
#     171 # Failed to parse it as a compliant openEO API error: show body as-is in the exception.
#     172 text = response.text
#
# OpenEoApiError: [500] Internal: Server error: A part of your process graph failed multiple times. Simply try submitting again, or use batch job logs to find more detailed information in case of persistent failures. Increasing executor memory may help if the root cause is not clear from the logs. (ref: r-2604300717284c4aa36556e9758add85)

# %% [markdown]
# ## 7. Test: SCF Masks & Conditional Probabilities
#
# Test `compute_scf_masks` — this combines the simple snow mask with MODIS SCF to produce conditional probability inputs.

# %%
from openeo_mountains_snow.snowcoverarea_reconstruction.scf_processing import compute_scf_masks

all_masks, labels_scf = compute_scf_masks(eoconn, cfg, spatial_extent, temporal_extent)
print(f"SCF mask labels: {labels_scf}")

# Download to verify — use job_options from config for higher memory
job_options = OmegaConf.to_container(cfg.experiment.job_options, resolve=True)
all_masks.execute_batch("test_scf_masks.nc", job_options=job_options)
ds_masks = xr.open_dataset("test_scf_masks.nc")
print(ds_masks)
# Out:
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# ✅ SCF mask labels: ['scf_0_10', 'scf_10_20', 'scf_20_30', 'scf_30_40', 'scf_40_50', 'scf_50_60', 'scf_60_70', 'scf_70_80', 'scf_80_90', 'scf_90_100']
# 0:00:00 Job 'j-2604231113154cfd93fdb91e818fd3ab': send 'start'
# 0:00:24 Job 'j-2604231113154cfd93fdb91e818fd3ab': created (progress 0%)
# 0:00:29 Job 'j-2604231113154cfd93fdb91e818fd3ab': created (progress 0%)
# 0:00:36 Job 'j-2604231113154cfd93fdb91e818fd3ab': created (progress 0%)
# 0:00:44 Job 'j-2604231113154cfd93fdb91e818fd3ab': created (progress 0%)
# 0:00:54 Job 'j-2604231113154cfd93fdb91e818fd3ab': created (progress 0%)
# 0:01:07 Job 'j-2604231113154cfd93fdb91e818fd3ab': queued (progress 0%)
# 0:01:22 Job 'j-2604231113154cfd93fdb91e818fd3ab': queued (progress 0%)
# 0:01:43 Job 'j-2604231113154cfd93fdb91e818fd3ab': queued (progress 0%)
# 0:02:09 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:02:41 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:03:21 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:04:10 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:05:11 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:06:13 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:07:15 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:08:16 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:09:18 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:10:21 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:11:24 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:12:26 Job 'j-2604231113154cfd93fdb91e818fd3ab': running (progress N/A)
# 0:13:30 Job 'j-2604231113154cfd93fdb91e818fd3ab': finished (progress 100%)
# <xarray.Dataset> Size: 96MB
# Dimensions:     (t: 2, x: 1000, y: 1000)
# Coordinates:
#   * t           (t) datetime64[ns] 16B 2023-01-11 2023-01-13
#   * x           (x) float64 8kB 6.35e+05 6.35e+05 6.35e+05 ... 6.45e+05 6.45e+05
#   * y           (y) float64 8kB 5.18e+06 5.18e+06 5.18e+06 ... 5.17e+06 5.17e+06
# Data variables: (12/13)
#     crs         |S1 1B ...
#     scf_0_10    (t, y, x) float32 8MB ...
#     scf_10_20   (t, y, x) float32 8MB ...
#     scf_20_30   (t, y, x) float32 8MB ...
#     scf_30_40   (t, y, x) float32 8MB ...
#     scf_40_50   (t, y, x) float32 8MB ...
#     ...          ...
#     scf_60_70   (t, y, x) float32 8MB ...
#     scf_70_80   (t, y, x) float32 8MB ...
#     scf_80_90   (t, y, x) float32 8MB ...
#     scf_90_100  (t, y, x) float32 8MB ...
#     valid       (t, y, x) float32 8MB ...
#     snow        (t, y, x) float32 8MB ...
# Attributes:
#     Conventions:  CF-1.9
#     institution:  Copernicus Data Space Ecosystem openEO API - 0.71.0a28.dev2...
#     description:
#     title:

# %% [markdown]
# ## 8. Test: Downscale Temperature & Humidity
#
# Test climate downscaling independently. This loads AGERA5, DEM, and geopotential.

# %%
from openeo_mountains_snow.snowcoverarea_reconstruction.downscale_variables import (
    downscale_temperature_humidity, downscale_shortwave_radiation,
)
job_options = OmegaConf.to_container(cfg.experiment.job_options, resolve=True)

# Use a fixed date for time dimension
first_date = temporal_extent[0]

# DEM
dem = eoconn.load_collection("COPERNICUS_30", spatial_extent=spatial_extent)
if dem.metadata.has_temporal_dimension():
    dem = dem.reduce_dimension(dimension="t", reducer="max")
dem = dem.add_dimension(name="t", label=first_date, type="temporal")

# AGERA5
agera = eoconn.load_stac(
    cfg.agera5.stac_url,
    spatial_extent=spatial_extent,
    temporal_extent=agera_temporal_extent,
)
agera = agera.filter_bands(bands=list(cfg.agera5.bands))
agera = agera.rename_labels(dimension="bands", target=list(cfg.agera5.band_aliases))

# Geopotential — single global STAC Feature: load_stac can't filter it,
# so we load the full item then crop with filter_bbox server-side.
geopotential = eoconn.load_stac(
    cfg.geopotential.stac_url,
    spatial_extent=spatial_extent,
    bands=["geopotential"],
)


#TODO fix issue with geopotential
agera_downscaled =agera
#agera_downscaled = downscale_temperature_humidity(agera, dem, geopotential.max_time())

agera_downscaled.execute_batch("test_agera_downscaled.nc", job_options=job_options)
ds_agera = xr.open_dataset("test_agera_downscaled.nc")

print(ds_agera)

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
for i, var in enumerate(ds_agera.data_vars):
    if ds_agera[var].dims == ("t", "y", "x"):
        ds_agera[var].isel(t=0).plot(ax=axes[i])
        axes[i].set_title(var)
plt.tight_layout()
plt.show()
# Out:
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# 0:00:00 Job 'j-260428112513491999837d63a2840416': send 'start'
# 0:00:18 Job 'j-260428112513491999837d63a2840416': created (progress 0%)
# 0:00:23 Job 'j-260428112513491999837d63a2840416': created (progress 0%)
# 0:00:29 Job 'j-260428112513491999837d63a2840416': created (progress 0%)
# 0:00:37 Job 'j-260428112513491999837d63a2840416': created (progress 0%)
# 0:00:47 Job 'j-260428112513491999837d63a2840416': created (progress 0%)
# 0:01:00 Job 'j-260428112513491999837d63a2840416': created (progress 0%)
# 0:01:15 Job 'j-260428112513491999837d63a2840416': running (progress N/A)
# 0:01:34 Job 'j-260428112513491999837d63a2840416': running (progress N/A)
# 0:01:59 Job 'j-260428112513491999837d63a2840416': running (progress N/A)
# 0:02:29 Job 'j-260428112513491999837d63a2840416': finished (progress 100%)
# <xarray.Dataset> Size: 313B
# Dimensions:               (t: 5, x: 2, y: 2)
# Coordinates:
#   * t                     (t) datetime64[ns] 40B 2023-01-10 ... 2023-01-14
#   * x                     (x) float64 16B 10.8 10.9
#   * y                     (y) float64 16B 46.8 46.7
# Data variables:
#     crs                   |S1 1B ...
#     temperature-mean      (t, y, x) float32 80B ...
#     dewpoint-temperature  (t, y, x) float32 80B ...
#     solar-radiation-flux  (t, y, x) float32 80B ...
# Attributes:
#     Conventions:  CF-1.9
#     institution:  Copernicus Data Space Ecosystem openEO API - 0.72.0a3.dev20...
#     description:
#     title:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 45
#      43 for i, var in enumerate(ds_agera.data_vars):
#      44     if ds_agera[var].dims == ("t", "y", "x"):
# ---> 45         ds_agera[var].isel(t=0).plot(ax=axes[i])
#      46         axes[i].set_title(var)
#      47 plt.tight_layout()
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %% [markdown]
# ## 9. Test: Downscale Shortwave Radiation

# %%
import importlib
from openeo_mountains_snow.snowcoverarea_reconstruction import downscale_variables
importlib.reload(downscale_variables)
from openeo_mountains_snow.snowcoverarea_reconstruction.downscale_variables import (
    downscale_shortwave_radiation,
)

aspect = eoconn.load_stac(
    cfg.dem.aspect_stac_url, spatial_extent=spatial_extent
).reduce_dimension(dimension="t", reducer="mean")

slope = eoconn.load_stac(
    cfg.dem.slope_stac_url, spatial_extent=spatial_extent
).reduce_dimension(dimension="t", reducer="mean")

slope_aspect = aspect.merge_cubes(slope).rename_labels(
    dimension="bands", target=["aspect", "slope"]
)

shortwave_rad_cube = downscale_shortwave_radiation(agera, slope_aspect)

# UDFs declare `pvlib` via PEP 723 inline metadata, which is only honored by
# batch jobs (not synchronous .download()), so use execute_batch here.
shortwave_rad_cube.execute_batch("test_shortwave.nc", job_options=job_options)
ds_sw = xr.open_dataset("test_shortwave.nc")
print(ds_sw)
# Out:
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# 0:00:00 Job 'j-2604281143264553ac768051666e201d': send 'start'
# 0:00:18 Job 'j-2604281143264553ac768051666e201d': created (progress 0%)
# 0:00:23 Job 'j-2604281143264553ac768051666e201d': created (progress 0%)
# 0:00:36 Job 'j-2604281143264553ac768051666e201d': created (progress 0%)
# 0:00:44 Job 'j-2604281143264553ac768051666e201d': created (progress 0%)
# 0:00:54 Job 'j-2604281143264553ac768051666e201d': queued (progress 0%)
# 0:01:06 Job 'j-2604281143264553ac768051666e201d': queued (progress 0%)
# 0:01:22 Job 'j-2604281143264553ac768051666e201d': queued (progress 0%)
# 0:01:41 Job 'j-2604281143264553ac768051666e201d': queued (progress 0%)
# 0:02:16 Job 'j-2604281143264553ac768051666e201d': running (progress N/A)
# 0:02:46 Job 'j-2604281143264553ac768051666e201d': running (progress N/A)
# 0:03:23 Job 'j-2604281143264553ac768051666e201d': running (progress N/A)
# 0:04:10 Job 'j-2604281143264553ac768051666e201d': running (progress N/A)
# 0:05:09 Job 'j-2604281143264553ac768051666e201d': running (progress N/A)
# 0:06:09 Job 'j-2604281143264553ac768051666e201d': running (progress N/A)
# 0:07:16 Job 'j-2604281143264553ac768051666e201d': finished (progress 100%)
# <xarray.Dataset> Size: 265B
# Dimensions:               (t: 5, x: 2, y: 1)
# Coordinates:
#   * t                     (t) datetime64[ns] 40B 2023-01-10 ... 2023-01-14
#   * x                     (x) float64 16B 10.81 10.91
#   * y                     (y) float64 8B 46.72
# Data variables:
#     crs                   |S1 1B ...
#     solar-radiation-flux  (t, y, x) float32 40B ...
#     zenith                (t, y, x) float32 40B ...
#     azimuth               (t, y, x) float32 40B ...
#     aspect                (t, y, x) float32 40B ...
#     slope                 (t, y, x) float32 40B ...
# Attributes:
#     Conventions:  CF-1.9
#     institution:  Copernicus Data Space Ecosystem openEO API - 0.72.0a3.dev20...
#     description:
#     title:

# %% [markdown]
# ## 10. Chain it all together
#
# Once each step above works individually, chain them and run the full pipeline on the tiny extent.

# %%
# If all steps above passed, run the full pipeline on the tiny test extent
import importlib
from openeo_mountains_snow.snowcoverarea_reconstruction import pipeline as _pipeline
importlib.reload(_pipeline)
from openeo_mountains_snow.snowcoverarea_reconstruction.pipeline import run_reconstruction

# Override the experiment config to use our tiny test extent
test_cfg = OmegaConf.merge(cfg, {
    "experiment": {
        "aoi": spatial_extent,
        "temporal_extent": temporal_extent,
        "modis_temporal_extent": modis_temporal_extent,
        "agera_temporal_extent": agera_temporal_extent,
        "title_prefix": "test_baby_steps",
    }
})

run_reconstruction(test_cfg, eoconn, spatial_extent)
#print("🎉 Uncomment the line above when ready to run the full pipeline.")
# Out:
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# 0:00:00 Job 'j-26042813330743c0959ed662f5eaf39a': send 'start'
# 0:00:22 Job 'j-26042813330743c0959ed662f5eaf39a': created (progress 0%)
# 0:00:27 Job 'j-26042813330743c0959ed662f5eaf39a': created (progress 0%)
# 0:00:34 Job 'j-26042813330743c0959ed662f5eaf39a': created (progress 0%)
# 0:00:42 Job 'j-26042813330743c0959ed662f5eaf39a': created (progress 0%)
# 0:00:52 Job 'j-26042813330743c0959ed662f5eaf39a': created (progress 0%)
# 0:01:05 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:01:21 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:01:40 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:02:05 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:02:35 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:03:13 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:04:00 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:04:58 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:05:59 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:06:59 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:08:00 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:09:00 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:10:00 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:11:01 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:12:01 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:13:01 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:14:02 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:15:02 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:16:03 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:17:03 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:18:04 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:19:05 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:20:06 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:21:06 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:22:07 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:23:08 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:24:15 Job 'j-26042813330743c0959ed662f5eaf39a': running (progress N/A)
# 0:25:16 Job 'j-26042813330743c0959ed662f5eaf39a': error (progress N/A)
# Your batch job 'j-26042813330743c0959ed662f5eaf39a' failed. Error logs:
# [{'id': '[1777384620415, 690113]', 'time': '2026-04-28T13:57:00.415Z', 'level': 'error', 'message': 'Task 6881 in stage 514.0 failed 4 times; aborting job'}, {'id': '[1777384620422, 584249]', 'time': '2026-04-28T13:57:00.422Z', 'level': 'error', 'message': 'Stage error: Job aborted due to stage failure: Task 6881 in stage 514.0 failed 4 times, most recent failure: Lost task 6881.3 in stage 514.0 (TID 24472) (10.42.238.233 executor 2): java.lang.IllegalArgumentException: The number of bands in the metadata 3/5 does not match the actual band count in the cubes (left/right): 3/1. You can fix this by explicitly specifying correct band labels.\n\tat org.openeo.geotrellis.OpenEOProcesses.$anonfun$combine_bands$1(OpenEOProcesses.scala:1291)\n\tat org.apache.spark.rdd.PairRDDFunctions.$anonfun$mapValues$3(PairRDDFunctions.scala:754)\n\tat scala.collection.Iterator$$anon$9.next(Iterator.scala:584)\n\tat scala.collection.Iterator$$anon$6.hasNext(Iterator.scala:478)\n\tat scala.collection.Iterator$$anon$9.hasNext(Iterator.scala:583)\n\tat scala.collection.Iterator$$anon$9.hasNext(Iterator.scala:583)\n\tat org.apache.spark.api.python.PythonRDD$.writeNextElementToStream(PythonRDD.scala:333)\n\tat org.apache.spark.api.python.PythonRunner$$anon$2.writeNextInputToStream(PythonRunner.scala:906)\n\tat org.apache.spark.api.python.BasePythonRunner$ReaderInputStream.writeAdditionalInputToPythonWorker(PythonRunner.scala:844)\n\tat org.apache.spark.api.python.BasePythonRunner$ReaderInputStream.read(PythonRunner.scala:767)\n\tat java.base/java.io.BufferedInputStream.fill(BufferedInputStream.java:291)\n\tat java.base/java.io.BufferedInputStream.read1(BufferedInputStream.java:347)\n\tat java.base/java.io.BufferedInputStream.implRead(BufferedInputStream.java:420)\n\tat java.base/java.io.BufferedInputStream.read(BufferedInputStream.java:399)\n\tat java.base/java.io.DataInputStream.readFully(DataInputStream.java:208)\n\tat java.base/java.io.DataInputStream.readInt(DataInputStream.java:385)\n\tat org.apache.spark.api.python.PythonRunner$$anon$3.read(PythonRunner.scala:933)\n\tat org.apache.spark.api.python.PythonRunner$$anon$3.read(PythonRunner.scala:925)\n\tat org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:532)\n\tat org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)\n\tat scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:263)\n\tat scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:265)\n\tat scala.collection.Iterator$$anon$9.hasNext(Iterator.scala:583)\n\tat org.apache.spark.shuffle.sort.UnsafeShuffleWriter.write(UnsafeShuffleWriter.java:181)\n\tat org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:57)\n\tat org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:111)\n\tat org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)\n\tat org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:171)\n\tat org.apache.spark.scheduler.Task.run(Task.scala:147)\n\tat org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$5(Executor.scala:647)\n\tat org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally(SparkErrorUtils.scala:80)\n\tat org.apache.spark.util.SparkErrorUtils.tryWithSafeFinally$(SparkErrorUtils.scala:77)\n\tat org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:99)\n\tat org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:650)\n\tat java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)\n\tat java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)\n\tat java.base/java.lang.Thread.run(Thread.java:1583)\n\nDriver stacktrace:'}, {'id': '[1777384622266, 777762]', 'time': '2026-04-28T13:57:02.266Z', 'level': 'error', 'message': 'OpenEO batch job failed: Exception during Spark execution: java.lang.IllegalArgumentException: The number of bands in the metadata 3/5 does not match the actual band cou ...
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-26042813330743c0959ed662f5eaf39a').logs()`.
# ---------------------------------------------------------------------------
# JobFailedException                        Traceback (most recent call last)
# Cell In[23], line 19
#       8 test_cfg = OmegaConf.merge(cfg, {
#       9     "experiment": {
#      10         "aoi": spatial_extent,
#    (...)     15     }
#      16 })
#      18 # This will submit a batch job — use only when you're confident each step works!
# ---> 19 run_reconstruction(test_cfg, eoconn, spatial_extent)
#      20 #print("🎉 Uncomment the line above when ready to run the full pipeline.")
#
# File c:\Git_projects\openeo_mountains_snow\src\openeo_mountains_snow\snowcoverarea_reconstruction\pipeline.py:176, in run_reconstruction(cfg, eoconn, spatial_extent)
#     171 # ==============================
#     172 # 8. Execute Batch Job
#     173 # ==============================
#     175 job_options = OmegaConf.to_container(exp.job_options, resolve=True)
# --> 176 swe.execute_batch(
#     177     title=exp.title_prefix or "swe",
#     178     job_options=job_options,
#     179 )
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\datacube.py:2683, in DataCube.execute_batch(self, outputfile, out_format, title, description, plan, budget, print, max_poll_interval, connection_retry_interval, additional, job_options, validate, auto_add_save_result, show_error_logs, log_level, **format_options)
#    2670     create_kwargs = {"auto_add_save_result": False}
#    2672 job = res.create_job(
#    2673     title=title,
#    2674     description=description,
#    (...)   2681     **create_kwargs,
#    2682 )
# -> 2683 job.start_and_wait(
#    2684     print=print,
#    2685     max_poll_interval=max_poll_interval,
#    2686     connection_retry_interval=connection_retry_interval,
#    2687     show_error_logs=show_error_logs,
#    2688 )
#    2689 if outputfile is not None:
#    2690     job.download_result(target=outputfile)
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\job.py:382, in BatchJob.start_and_wait(self, print, max_poll_interval, connection_retry_interval, soft_error_max, show_error_logs, require_success)
#     378         print(self.logs(level=logging.ERROR))
#     379         print(
#     380             f"Full logs can be inspected in an openEO (web) editor or with `connection.job({self.job_id!r}).logs()`."
#     381         )
# --> 382     raise JobFailedException(
#     383         f"Batch job {self.job_id!r} didn't finish successfully. Status: {status} (after {elapsed()}).",
#     384         job=self,
#     385     )
#     387 return self
#
# JobFailedException: Batch job 'j-26042813330743c0959ed662f5eaf39a' didn't finish successfully. Status: error (after 0:25:17).

# %%
import importlib
from openeo_mountains_snow.snowcoverarea_reconstruction import (
    downscale_variables,
    pipeline as _pipeline,
)

# Ensure the notebook uses the latest on-disk implementations.
importlib.reload(downscale_variables)
importlib.reload(_pipeline)
from openeo_mountains_snow.snowcoverarea_reconstruction.pipeline import run_reconstruction

exp = cfg.experiment

test_cfg = OmegaConf.merge(cfg, {
    "experiment": {
        "aoi": spatial_extent,
        "temporal_extent": list(exp.temporal_extent),
        "modis_temporal_extent": list(exp.modis_temporal_extent),
        "agera_temporal_extent": list(exp.agera_temporal_extent),
        "title_prefix": exp.title_prefix or "swe",
        "job_options": exp.job_options,
    }
})

run_reconstruction(test_cfg, eoconn, spatial_extent)
# Out:
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# Deriving band listing from unordered `item_assets`
# Using 'eo:bands' metadata, but STAC extension eo was not declared.
# 0:00:00 Job 'j-26042906440547438e35f745accaa453': send 'start'
# 0:00:28 Job 'j-26042906440547438e35f745accaa453': created (progress 0%)
# 0:00:33 Job 'j-26042906440547438e35f745accaa453': created (progress 0%)
# 0:00:39 Job 'j-26042906440547438e35f745accaa453': created (progress 0%)
# 0:00:48 Job 'j-26042906440547438e35f745accaa453': created (progress 0%)
# 0:00:58 Job 'j-26042906440547438e35f745accaa453': created (progress 0%)
# 0:01:10 Job 'j-26042906440547438e35f745accaa453': created (progress 0%)
# 0:01:26 Job 'j-26042906440547438e35f745accaa453': queued (progress 0%)
# 0:01:47 Job 'j-26042906440547438e35f745accaa453': queued (progress 0%)
# 0:02:11 Job 'j-26042906440547438e35f745accaa453': queued (progress 0%)
# 0:02:41 Job 'j-26042906440547438e35f745accaa453': queued (progress 0%)
# 0:03:19 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:04:06 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:05:09 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:06:09 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:07:09 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:08:10 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:09:10 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:10:11 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:11:11 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:12:11 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:13:12 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:14:12 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:15:13 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:16:13 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:17:14 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:18:14 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:19:15 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:20:15 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:21:15 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:22:16 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:23:16 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:24:16 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:25:17 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:26:17 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:27:18 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:28:18 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:29:19 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:30:21 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:31:22 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:32:22 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:33:23 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:34:23 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:35:24 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:36:24 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:37:24 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:38:25 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:39:25 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:40:26 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:41:26 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:42:27 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:43:28 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:44:28 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:45:29 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:46:29 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:47:29 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:48:30 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:49:31 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:50:32 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:51:32 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:52:33 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:53:33 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:54:34 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:55:34 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:56:35 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:57:36 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:58:36 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 0:59:37 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:00:37 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:01:38 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:02:38 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:03:38 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:04:39 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:05:39 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:06:40 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:07:41 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:08:42 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:09:43 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:10:44 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:11:45 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:12:45 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:13:46 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:14:47 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:15:47 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:16:47 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:17:48 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:18:56 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:19:57 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:20:58 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:21:59 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:22:59 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:24:00 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:25:01 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:26:02 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:27:02 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:28:02 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:29:03 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:30:03 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:31:04 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:32:04 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:33:05 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:34:06 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:35:06 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:36:07 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:37:08 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:38:08 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:39:09 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:40:09 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:41:10 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:42:10 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:43:11 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:44:11 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:45:12 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:46:12 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:47:13 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:48:13 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:49:14 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:50:15 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:51:16 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:52:17 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:53:18 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:54:18 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:55:19 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:56:20 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:57:21 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:58:22 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 1:59:23 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:00:23 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:01:24 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:02:24 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:03:25 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:04:25 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:05:26 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:06:27 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:07:27 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:08:28 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:09:29 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:10:29 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:11:30 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:12:30 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:13:32 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:14:33 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:15:33 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:16:34 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:17:34 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:18:35 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:19:35 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:20:36 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:21:37 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:22:37 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:23:38 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:24:38 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:25:39 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:26:40 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:27:40 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:28:40 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:29:41 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:30:41 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:31:42 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:32:42 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:33:43 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:34:43 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:35:43 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:36:44 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:37:45 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:38:46 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:39:47 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:40:48 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:41:49 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:42:49 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:43:50 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:44:51 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:45:51 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:46:52 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:47:52 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:48:53 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:49:54 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:50:55 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:51:56 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:52:57 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:53:58 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:54:58 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:56:01 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:57:01 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:58:03 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 2:59:04 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:00:04 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:01:05 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:02:05 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:03:06 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:04:06 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:05:07 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:06:07 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:07:08 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:08:09 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:09:09 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:10:10 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:11:11 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:12:14 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:13:18 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:14:19 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:15:20 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:16:21 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:17:22 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:18:22 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:19:23 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:20:24 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:21:25 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:22:25 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:23:26 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:24:27 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:25:28 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:26:28 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:27:29 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:28:29 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:29:30 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:30:30 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:31:31 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:32:32 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:33:32 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:34:33 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:35:34 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:36:34 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:37:35 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:38:35 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:39:35 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:40:36 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:41:36 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:42:37 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:43:38 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:44:39 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:45:39 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:46:40 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:47:41 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:48:42 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:49:43 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:50:43 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:51:44 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:52:45 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:53:45 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:54:46 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 3:55:47 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:18:21 Job 'j-26042906440547438e35f745accaa453': Connection error while polling job status: HTTPSConnectionPool(host='openeo.dataspace.copernicus.eu', port=443): Max retries exceeded with url: /openeo/1.2/jobs/j-26042906440547438e35f745accaa453 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x00000277C9AD1C50>: Failed to resolve 'openeo.dataspace.copernicus.eu' ([Errno 11001] getaddrinfo failed)"))
# 4:18:52 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:19:53 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:20:59 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:22:00 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:23:02 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:24:03 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:25:04 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:26:05 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:27:05 Job 'j-26042906440547438e35f745accaa453': running (progress N/A)
# 4:28:06 Job 'j-26042906440547438e35f745accaa453': canceled (progress N/A)
# Your batch job 'j-26042906440547438e35f745accaa453' failed. Error logs:
# [{'id': '[1777454808257, 448299]', 'time': '2026-04-29T09:26:48.257Z', 'level': 'error', 'message': 'Uncaught exception in thread Thread[#57,Executor task launch worker for task 0.0 in stage 390.0 (TID 6064),5,main]'}, {'id': '[1777454808273, 766236]', 'time': '2026-04-29T09:26:48.273Z', 'level': 'error', 'message': 'Ignoring error'}, {'id': '[1777454811092, 675949]', 'time': '2026-04-29T09:26:51.092Z', 'level': 'error', 'message': 'Lost executor 12 on 10.42.193.7: \nThe executor with id 12 exited with exit code 52(JVM OOM).\n\n\n\nThe API gave the following container statuses:\n\n\n\t container name: spark-kubernetes-executor\n\t container image: registry.internal/prod/openeo-geotrellis-kube-python311:20260428-666\n\t container state: terminated\n\t container started at: 2026-04-29T07:09:25Z\n\t container finished at: 2026-04-29T09:26:49Z\n\t exit code: 52\n\t termination reason: Error\n      '}, {'id': '[1777454865319, 214618]', 'time': '2026-04-29T09:27:45.319Z', 'level': 'error', 'message': 'Missing an output location for shuffle 168 partition 3'}, {'id': '[1777454865330, 25554]', 'time': '2026-04-29T09:27:45.330Z', 'level': 'error', 'message': 'Missing an output location for shuffle 168 partition 0'}, {'id': '[1777454865339, 107802]', 'time': '2026-04-29T09:27:45.339Z', 'level': 'error', 'message': 'Stage error: org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 168 partition 3\n\tat org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1770)\n\tat org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1715)\n\tat org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1714)\n\tat scala.collection.IterableOnceOps.foreach(IterableOnce.scala:619)\n\tat scala.collection.IterableOnceOps.foreach$(IterableOnce.scala:617)\n\tat scala.collection.AbstractIterator.foreach(Iterator.scala:1306)\n\tat org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1714)\n\tat org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1348)\n\tat org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1310)\n\tat org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:135)\n\tat org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:67)\n\tat org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:61)\n\tat org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)\n\tat org.apache.spark.rdd.ShuffledRDD.compute(ShuffledRDD.scala:106)\n\tat org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:374)\n\tat org.apache.spark.rdd.RDD.iterator(RDD.scala:338)\n\tat geotrellis.spark.ContextRDD.compute(ContextRDD.scala:36)\n\tat org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:374)\n\tat org.apache.spark.rdd.RDD.iterator(RDD.scala:338)\n\tat geotrellis.spark.ContextRDD.compute(ContextRDD.scala:36)\n\tat org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:374)\n\tat org.apache.spark.rdd.RDD.iterator(RDD.scala:338)\n\tat org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)\n\tat org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:374)\n\tat org.apache.spark.rdd.RDD.iterator(RDD.scala:338)\n\tat geotrellis.spark.ContextRDD.compute(ContextRDD.scala:36)\n\tat org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:374)\n\tat org.apache.spark.rdd.RDD.iterator(RDD.scala:338)\n\tat org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)\n\tat org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:374)\n\tat org.apache.spark.rdd.RDD.iterator(RDD.scala:338)\n\tat org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:107)\n\tat org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:54)\n\tat org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.sca ...
# Full logs can be inspected in an openEO (web) editor or with `connection.job('j-26042906440547438e35f745accaa453').logs()`.
# ---------------------------------------------------------------------------
# JobFailedException                        Traceback (most recent call last)
# Cell In[25], line 25
#      12 exp = cfg.experiment
#      14 test_cfg = OmegaConf.merge(cfg, {
#      15     "experiment": {
#      16         "aoi": spatial_extent,
#    (...)     22     }
#      23 })
# ---> 25 run_reconstruction(test_cfg, eoconn, spatial_extent)
#
# File c:\Git_projects\openeo_mountains_snow\src\openeo_mountains_snow\snowcoverarea_reconstruction\pipeline.py:176, in run_reconstruction(cfg, eoconn, spatial_extent)
#     171 # ==============================
#     172 # 8. Execute Batch Job
#     173 # ==============================
#     175 job_options = OmegaConf.to_container(exp.job_options, resolve=True)
# --> 176 swe.execute_batch(
#     177     title=exp.title_prefix or "swe",
#     178     job_options=job_options,
#     179 )
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\datacube.py:2683, in DataCube.execute_batch(self, outputfile, out_format, title, description, plan, budget, print, max_poll_interval, connection_retry_interval, additional, job_options, validate, auto_add_save_result, show_error_logs, log_level, **format_options)
#    2670     create_kwargs = {"auto_add_save_result": False}
#    2672 job = res.create_job(
#    2673     title=title,
#    2674     description=description,
#    (...)   2681     **create_kwargs,
#    2682 )
# -> 2683 job.start_and_wait(
#    2684     print=print,
#    2685     max_poll_interval=max_poll_interval,
#    2686     connection_retry_interval=connection_retry_interval,
#    2687     show_error_logs=show_error_logs,
#    2688 )
#    2689 if outputfile is not None:
#    2690     job.download_result(target=outputfile)
#
# File c:\Users\VROMPAYH\AppData\Local\anaconda3\envs\py311\Lib\site-packages\openeo\rest\job.py:382, in BatchJob.start_and_wait(self, print, max_poll_interval, connection_retry_interval, soft_error_max, show_error_logs, require_success)
#     378         print(self.logs(level=logging.ERROR))
#     379         print(
#     380             f"Full logs can be inspected in an openEO (web) editor or with `connection.job({self.job_id!r}).logs()`."
#     381         )
# --> 382     raise JobFailedException(
#     383         f"Batch job {self.job_id!r} didn't finish successfully. Status: {status} (after {elapsed()}).",
#     384         job=self,
#     385     )
#     387 return self
#
# JobFailedException: Batch job 'j-26042906440547438e35f745accaa453' didn't finish successfully. Status: canceled (after 4:28:08).
